# %% [markdown]
# # Imports

# %%
import plip.structure.preparation
import pandas as pd
from asapdiscovery.data.backend.plip import get_interactions_plip
from asapdiscovery.modeling.modeling import split_openeye_mol
from asapdiscovery.data.backend.openeye import (
    load_openeye_sdf,
    load_openeye_pdb
)
from pathlib import Path
from plip.structure.preparation import PDBComplex
from plip_analysis import get_plip_interactions

# %% [markdown]
# # Load Structures

# %%
docked_path = Path("example_structures/ASAP-0000153_min.pdb")
xtal_path = Path("example_structures/SARS_A0181_ASAP-0000153-001_refine_min.pdb")

# %%
# xtal = load_openeye_pdb(xtal_path)
# docked = load_openeye_pdb(docked_path)

# %%
# xtal_split_dict = split_openeye_mol(xtal)

# %%
# results = get_interactions_plip(xtal_split_dict['prot'], xtal_split_dict['lig'], "fitness", "SARS-CoV-2-Mpro")

# %%
# results

# %%
# my_mol = PDBComplex()
# my_mol.load_pdb(str(docked_path))

# %%
# print(my_mol)

# %%
# mybsid = 'UNK:2:299'

# %%
# my_mol.interaction_sets

# %%
# my_mol.ligands[0]

# %%
# my_mol.characterize_complex(my_mol.ligands[0])

# %%
ints = get_plip_interactions(docked_path)
